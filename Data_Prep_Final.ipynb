# %% [markdown]
# #Imports

# %%
from google.colab import drive
from google.colab import files
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns

drive.mount('/content/drive')
myDrive = '/content/drive/Shareddrives/Deep_Learning_2024/Final/Data/Mixed_ETF/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_names = ['vaw.us.txt','vcr.us.txt','vgt.us.txt','vfh.us.txt','vde.us.txt','vht.us.txt','vnq.us.txt']
data_files = {}
for name in file_names:
  file_path = os.path.join(myDrive,name)
  data_files[name] = pd.read_csv(file_path, sep=",", header=0)

# %%
data_files['vaw.us.txt'].head()
# Out:
#          Date    Open    High     Low   Close  Volume  OpenInt
# 0  2005-02-25  54.737  55.614  54.737  55.594   20156        0
# 1  2005-02-28  55.728  55.728  54.855  55.194   47699        0
# 2  2005-03-01  55.418  55.640  55.041  55.130   17578        0
# 3  2005-03-02  54.649  55.263  54.649  55.085   11532        0
# 4  2005-03-03  55.409  55.409  54.855  55.122   28440        0

# %%
#data_files['vaw.us.txt']
for name in file_names:
  print(data_files[name].shape)
# Out:
# (3201, 7)
# (3201, 7)
# (3201, 7)
# (3201, 7)
# (3201, 7)
# (3201, 7)
# (3201, 7)

# %% [markdown]
# # Check same dates

# %%
reference_df = data_files['vaw.us.txt']

min_length = min(df.shape[0] for df in data_files.values())
rows_to_check = min(3201, min_length)

for name in file_names:
    if name != 'vaw.us.txt':
        for i in range(rows_to_check):
            if data_files[name].loc[i, 'Date'] == reference_df.loc[i, 'Date']:
                print(f'FUCK we have a mismatch at row {i} in file {name}')
# Out:
# Streaming output truncated to the last 5000 lines.
# FUCK we have a mismatch at row 1402 in file vht.us.txt
# FUCK we have a mismatch at row 1403 in file vht.us.txt
# FUCK we have a mismatch at row 1404 in file vht.us.txt
# FUCK we have a mismatch at row 1405 in file vht.us.txt
# FUCK we have a mismatch at row 1406 in file vht.us.txt
# FUCK we have a mismatch at row 1407 in file vht.us.txt
# FUCK we have a mismatch at row 1408 in file vht.us.txt
# FUCK we have a mismatch at row 1409 in file vht.us.txt
# FUCK we have a mismatch at row 1410 in file vht.us.txt
# FUCK we have a mismatch at row 1411 in file vht.us.txt
# FUCK we have a mismatch at row 1412 in file vht.us.txt
# FUCK we have a mismatch at row 1413 in file vht.us.txt
# FUCK we have a mismatch at row 1414 in file vht.us.txt
# FUCK we have a mismatch at row 1415 in file vht.us.txt
# FUCK we have a mismatch at row 1416 in file vht.us.txt
# FUCK we have a mismatch at row 1417 in file vht.us.txt
# FUCK we have a mismatch at row 1418 in file vht.us.txt
# FUCK we have a mismatch at row 1419 in file vht.us.txt
# FUCK we have a mismatch at row 1420 in file vht.us.txt
# FUCK we have a mismatch at row 1421 in file vht.us.txt
# FUCK we have a mismatch at row 1422 in file vht.us.txt
# FUCK we have a mismatch at row 1423 in file vht.us.txt
# FUCK we have a mismatch at row 1424 in file vht.us.txt
# FUCK we have a mismatch at row 1425 in file vht.us.txt
# FUCK we have a mismatch at row 1426 in file vht.us.txt
# FUCK we have a mismatch at row 1427 in file vht.us.txt
# FUCK we have a mismatch at row 1428 in file vht.us.txt
# FUCK we have a mismatch at row 1429 in file vht.us.txt
# FUCK we have a mismatch at row 1430 in file vht.us.txt
# FUCK we have a mismatch at row 1431 in file vht.us.txt
# FUCK we have a mismatch at row 1432 in file vht.us.txt
# FUCK we have a mismatch at row 1433 in file vht.us.txt
# FUCK we have a mismatch at row 1434 in file vht.us.txt
# FUCK we have a mismatch at row 1435 in file vht.us.txt
# FUCK we have a mismatch at row 1436 in file vht.us.txt
# FUCK we have a mismatch at row 1437 in file vht.us.txt
# FUCK we have a mismatch at row 1438 in file vht.us.txt
# FUCK we have a mismatch at row 1439 in file vht.us.txt
# FUCK we have a mismatch at row 1440 in file vht.us.txt
# FUCK we have a mismatch at row 1441 in file vht.us.txt
# FUCK we have a mismatch at row 1442 in file vht.us.txt
# FUCK we have a mismatch at row 1443 in file vht.us.txt
# FUCK we have a mismatch at row 1444 in file vht.us.txt
# FUCK we have a mismatch at row 1445 in file vht.us.txt
# FUCK we have a mismatch at row 1446 in file vht.us.txt
# FUCK we have a mismatch at row 1447 in file vht.us.txt
# FUCK we have a mismatch at row 1448 in file vht.us.txt
# FUCK we have a mismatch at row 1449 in file vht.us.txt
# FUCK we have a mismatch at row 1450 in file vht.us.txt
# FUCK we have a mismatch at row 1451 in file vht.us.txt
# FUCK we have a mismatch at row 1452 in file vht.us.txt
# FUCK we have a mismatch at row 1453 in file vht.us.txt
# FUCK we have a mismatch at row 1454 in file vht.us.txt
# FUCK we have a mismatch at row 1455 in file vht.us.txt
# FUCK we have a mismatch at row 1456 in file vht.us.txt
# FUCK we have a mismatch at row 1457 in file vht.us.txt
# FUCK we have a mismatch at row 1458 in file vht.us.txt
# FUCK we have a mismatch at row 1459 in file vht.us.txt
# FUCK we have a mismatch at row 1460 in file vht.us.txt
# FUCK we have a mismatch at row 1461 in file vht.us.txt
# FUCK we have a mismatch at row 1462 in file vht.us.txt
# FUCK we have a mismatch at row 1463 in file vht.us.txt
# FUCK we have a mismatch at row 1464 in file vht.us.txt
# FUCK we have a mismatch at row 1465 in file vht.us.txt
# FUCK we have a mismatch at row 1466 in file vht.us.txt
# FUCK we have a mismatch at row 1467 in file vht.us.txt
# FUCK we have a mismatch at row 1468 in file vht.us.txt
# FUCK we have a mismatch at row 1469 in file vht.us.txt
# FUCK we have a mismatch at row 1470 in file vht.us.txt
# FUCK we have a mismatch at row 1471 in file vht.us.txt
# FUCK we have a mismatch at row 1472 in file vht.us.txt
# FUCK we have a mismatch at row 1473 in file vht.us.txt
# FUCK we have a mismatch at row 1474 in file vht.us.txt
# FUCK we have a mismatch at row 1475 in file vht.us.txt
# FUCK we have a mismatch at row 1476 in file vht.us.txt
# FUCK we have a mismatch at row 1477 in file vht.us.txt
# FUCK we have a mismatch at row 1478 in file vht.us.txt
# FUCK we have a mismatch at row 1479 in file vht.us.txt
# FUCK we have a mismatch at row 1480 in file vht.us.txt
# FUCK we have a mismatch at row 1481 in file vht.us.txt
# FUCK we have a mismatch at row 1482 in file vht.us.txt
# FUCK we have a mismatch at row 1483 in file vht.us.txt
# FUCK we have a mismatch at row 1484 in file vht.us.txt
# FUCK we have a mismatch at row 1485 in file vht.us.txt
# FUCK we have a mismatch at row 1486 in file vht.us.txt
# FUCK we have a mismatch at row 1487 in file vht.us.txt
# FUCK we have a mismatch at row 1488 in file vht.us.txt
# FUCK we have a mismatch at row 1489 in file vht.us.txt
# FUCK we have a mismatch at row 1490 in file vht.us.txt
# FUCK we have a mismatch at row 1491 in file vht.us.txt
# FUCK we have a mismatch at row 1492 in file vht.us.txt
# FUCK we have a mismatch at row 1493 in file vht.us.txt
# FUCK we have a mismatch at row 1494 in file vht.us.txt
# FUCK we have a mismatch at row 1495 in file vht.us.txt
# FUCK we have a mismatch at row 1496 in file vht.us.txt
# FUCK we have a mismatch at row 1497 in file vht.us.txt
# FUCK we have a mismatch at row 1498 in file vht.us.txt
# FUCK we have a mismatch at row 1499 in file vht.us.txt
# FUCK we have a mismatch at row 1500 in file vht.us.txt
# FUCK we have a mismatch at row 1501 in file vht.us.txt
# FUCK we have a mismatch at row 1502 in file vht.us.txt
# FUCK we have a mismatch at row 1503 in file vht.us.txt
# FUCK we have a mismatch at row 1504 in file vht.us.txt
# FUCK we have a mismatch at row 1505 in file vht.us.txt
# FUCK we have a mismatch at row 1506 in file vht.us.txt
# FUCK we have a mismatch at row 1507 in file vht.us.txt
# FUCK we have a mismatch at row 1508 in file vht.us.txt
# FUCK we have a mismatch at row 1509 in file vht.us.txt
# FUCK we have a mismatch at row 1510 in file vht.us.txt
# FUCK we have a mismatch at row 1511 in file vht.us.txt
# FUCK we have a mismatch at row 1512 in file vht.us.txt
# FUCK we have a mismatch at row 1513 in file vht.us.txt
# FUCK we have a mismatch at row 1514 in file vht.us.txt
# FUCK we have a mismatch at row 1515 in file vht.us.txt
# FUCK we have a mismatch at row 1516 in file vht.us.txt
# FUCK we have a mismatch at row 1517 in file vht.us.txt
# FUCK we have a mismatch at row 1518 in file vht.us.txt
# FUCK we have a mismatch at row 1519 in file vht.us.txt
# FUCK we have a mismatch at row 1520 in file vht.us.txt
# FUCK we have a mismatch at row 1521 in file vht.us.txt
# FUCK we have a mismatch at row 1522 in file vht.us.txt
# FUCK we have a mismatch at row 1523 in file vht.us.txt
# FUCK we have a mismatch at row 1524 in file vht.us.txt
# FUCK we have a mismatch at row 1525 in file vht.us.txt
# FUCK we have a mismatch at row 1526 in file vht.us.txt
# FUCK we have a mismatch at row 1527 in file vht.us.txt
# FUCK we have a mismatch at row 1528 in file vht.us.txt
# FUCK we have a mismatch at row 1529 in file vht.us.txt
# FUCK we have a mismatch at row 1530 in file vht.us.txt
# FUCK we have a mismatch at row 1531 in file vht.us.txt
# FUCK we have a mismatch at row 1532 in file vht.us.txt
# FUCK we have a mismatch at row 1533 in file vht.us.txt
# FUCK we have a mismatch at row 1534 in file vht.us.txt
# FUCK we have a mismatch at row 1535 in file vht.us.txt
# FUCK we have a mismatch at row 1536 in file vht.us.txt
# FUCK we have a mismatch at row 1537 in file vht.us.txt
# FUCK we have a mismatch at row 1538 in file vht.us.txt
# FUCK we have a mismatch at row 1539 in file vht.us.txt
# FUCK we have a mismatch at row 1540 in file vht.us.txt
# FUCK we have a mismatch at row 1541 in file vht.us.txt
# FUCK we have a mismatch at row 1542 in file vht.us.txt
# FUCK we have a mismatch at row 1543 in file vht.us.txt
# FUCK we have a mismatch at row 1544 in file vht.us.txt
# FUCK we have a mismatch at row 1545 in file vht.us.txt
# FUCK we have a mismatch at row 1546 in file vht.us.txt
# FUCK we have a mismatch at row 1547 in file vht.us.txt
# FUCK we have a mismatch at row 1548 in file vht.us.txt
# FUCK we have a mismatch at row 1549 in file vht.us.txt
# FUCK we have a mismatch at row 1550 in file vht.us.txt
# FUCK we have a mismatch at row 1551 in file vht.us.txt
# FUCK we have a mismatch at row 1552 in file vht.us.txt
# FUCK we have a mismatch at row 1553 in file vht.us.txt
# FUCK we have a mismatch at row 1554 in file vht.us.txt
# FUCK we have a mismatch at row 1555 in file vht.us.txt
# FUCK we have a mismatch at row 1556 in file vht.us.txt
# FUCK we have a mismatch at row 1557 in file vht.us.txt
# FUCK we have a mismatch at row 1558 in file vht.us.txt
# FUCK we have a mismatch at row 1559 in file vht.us.txt
# FUCK we have a mismatch at row 1560 in file vht.us.txt
# FUCK we have a mismatch at row 1561 in file vht.us.txt
# FUCK we have a mismatch at row 1562 in file vht.us.txt
# FUCK we have a mismatch at row 1563 in file vht.us.txt
# FUCK we have a mismatch at row 1564 in file vht.us.txt
# FUCK we have a mismatch at row 1565 in file vht.us.txt
# FUCK we have a mismatch at row 1566 in file vht.us.txt
# FUCK we have a mismatch at row 1567 in file vht.us.txt
# FUCK we have a mismatch at row 1568 in file vht.us.txt
# FUCK we have a mismatch at row 1569 in file vht.us.txt
# FUCK we have a mismatch at row 1570 in file vht.us.txt
# FUCK we have a mismatch at row 1571 in file vht.us.txt
# FUCK we have a mismatch at row 1572 in file vht.us.txt
# FUCK we have a mismatch at row 1573 in file vht.us.txt
# FUCK we have a mismatch at row 1574 in file vht.us.txt
# FUCK we have a mismatch at row 1575 in file vht.us.txt
# FUCK we have a mismatch at row 1576 in file vht.us.txt
# FUCK we have a mismatch at row 1577 in file vht.us.txt
# FUCK we have a mismatch at row 1578 in file vht.us.txt
# FUCK we have a mismatch at row 1579 in file vht.us.txt
# FUCK we have a mismatch at row 1580 in file vht.us.txt
# FUCK we have a mismatch at row 1581 in file vht.us.txt
# FUCK we have a mismatch at row 1582 in file vht.us.txt
# FUCK we have a mismatch at row 1583 in file vht.us.txt
# FUCK we have a mismatch at row 1584 in file vht.us.txt
# FUCK we have a mismatch at row 1585 in file vht.us.txt
# FUCK we have a mismatch at row 1586 in file vht.us.txt
# FUCK we have a mismatch at row 1587 in file vht.us.txt
# FUCK we have a mismatch at row 1588 in file vht.us.txt
# FUCK we have a mismatch at row 1589 in file vht.us.txt
# FUCK we have a mismatch at row 1590 in file vht.us.txt
# FUCK we have a mismatch at row 1591 in file vht.us.txt
# FUCK we have a mismatch at row 1592 in file vht.us.txt
# FUCK we have a mismatch at row 1593 in file vht.us.txt
# FUCK we have a mismatch at row 1594 in file vht.us.txt
# FUCK we have a mismatch at row 1595 in file vht.us.txt
# FUCK we have a mismatch at row 1596 in file vht.us.txt
# FUCK we have a mismatch at row 1597 in file vht.us.txt
# FUCK we have a mismatch at row 1598 in file vht.us.txt
# FUCK we have a mismatch at row 1599 in file vht.us.txt
# FUCK we have a mismatch at row 1600 in file vht.us.txt
# FUCK we have a mismatch at row 1601 in file vht.us.txt
# FUCK we have a mismatch at row 1602 in file vht.us.txt
# FUCK we have a mismatch at row 1603 in file vht.us.txt
# FUCK we have a mismatch at row 1604 in file vht.us.txt
# FUCK we have a mismatch at row 1605 in file vht.us.txt
# FUCK we have a mismatch at row 1606 in file vht.us.txt
# FUCK we have a mismatch at row 1607 in file vht.us.txt
# FUCK we have a mismatch at row 1608 in file vht.us.txt
# FUCK we have a mismatch at row 1609 in file vht.us.txt
# FUCK we have a mismatch at row 1610 in file vht.us.txt
# FUCK we have a mismatch at row 1611 in file vht.us.txt
# FUCK we have a mismatch at row 1612 in file vht.us.txt
# FUCK we have a mismatch at row 1613 in file vht.us.txt
# FUCK we have a mismatch at row 1614 in file vht.us.txt
# FUCK we have a mismatch at row 1615 in file vht.us.txt
# FUCK we have a mismatch at row 1616 in file vht.us.txt
# FUCK we have a mismatch at row 1617 in file vht.us.txt
# FUCK we have a mismatch at row 1618 in file vht.us.txt
# FUCK we have a mismatch at row 1619 in file vht.us.txt
# FUCK we have a mismatch at row 1620 in file vht.us.txt
# FUCK we have a mismatch at row 1621 in file vht.us.txt
# FUCK we have a mismatch at row 1622 in file vht.us.txt
# FUCK we have a mismatch at row 1623 in file vht.us.txt
# FUCK we have a mismatch at row 1624 in file vht.us.txt
# FUCK we have a mismatch at row 1625 in file vht.us.txt
# FUCK we have a mismatch at row 1626 in file vht.us.txt
# FUCK we have a mismatch at row 1627 in file vht.us.txt
# FUCK we have a mismatch at row 1628 in file vht.us.txt
# FUCK we have a mismatch at row 1629 in file vht.us.txt
# FUCK we have a mismatch at row 1630 in file vht.us.txt
# FUCK we have a mismatch at row 1631 in file vht.us.txt
# FUCK we have a mismatch at row 1632 in file vht.us.txt
# FUCK we have a mismatch at row 1633 in file vht.us.txt
# FUCK we have a mismatch at row 1634 in file vht.us.txt
# FUCK we have a mismatch at row 1635 in file vht.us.txt
# FUCK we have a mismatch at row 1636 in file vht.us.txt
# FUCK we have a mismatch at row 1637 in file vht.us.txt
# FUCK we have a mismatch at row 1638 in file vht.us.txt
# FUCK we have a mismatch at row 1639 in file vht.us.txt
# FUCK we have a mismatch at row 1640 in file vht.us.txt
# FUCK we have a mismatch at row 1641 in file vht.us.txt
# FUCK we have a mismatch at row 1642 in file vht.us.txt
# FUCK we have a mismatch at row 1643 in file vht.us.txt
# FUCK we have a mismatch at row 1644 in file vht.us.txt
# FUCK we have a mismatch at row 1645 in file vht.us.txt
# FUCK we have a mismatch at row 1646 in file vht.us.txt
# FUCK we have a mismatch at row 1647 in file vht.us.txt
# FUCK we have a mismatch at row 1648 in file vht.us.txt
# FUCK we have a mismatch at row 1649 in file vht.us.txt
# FUCK we have a mismatch at row 1650 in file vht.us.txt
# FUCK we have a mismatch at row 1651 in file vht.us.txt
# FUCK we have a mismatch at row 1652 in file vht.us.txt
# FUCK we have a mismatch at row 1653 in file vht.us.txt
# FUCK we have a mismatch at row 1654 in file vht.us.txt
# FUCK we have a mismatch at row 1655 in file vht.us.txt
# FUCK we have a mismatch at row 1656 in file vht.us.txt
# FUCK we have a mismatch at row 1657 in file vht.us.txt
# FUCK we have a mismatch at row 1658 in file vht.us.txt
# FUCK we have a mismatch at row 1659 in file vht.us.txt
# FUCK we have a mismatch at row 1660 in file vht.us.txt
# FUCK we have a mismatch at row 1661 in file vht.us.txt
# FUCK we have a mismatch at row 1662 in file vht.us.txt
# FUCK we have a mismatch at row 1663 in file vht.us.txt
# FUCK we have a mismatch at row 1664 in file vht.us.txt
# FUCK we have a mismatch at row 1665 in file vht.us.txt
# FUCK we have a mismatch at row 1666 in file vht.us.txt
# FUCK we have a mismatch at row 1667 in file vht.us.txt
# FUCK we have a mismatch at row 1668 in file vht.us.txt
# FUCK we have a mismatch at row 1669 in file vht.us.txt
# FUCK we have a mismatch at row 1670 in file vht.us.txt
# FUCK we have a mismatch at row 1671 in file vht.us.txt
# FUCK we have a mismatch at row 1672 in file vht.us.txt
# FUCK we have a mismatch at row 1673 in file vht.us.txt
# FUCK we have a mismatch at row 1674 in file vht.us.txt
# FUCK we have a mismatch at row 1675 in file vht.us.txt
# FUCK we have a mismatch at row 1676 in file vht.us.txt
# FUCK we have a mismatch at row 1677 in file vht.us.txt
# FUCK we have a mismatch at row 1678 in file vht.us.txt
# FUCK we have a mismatch at row 1679 in file vht.us.txt
# FUCK we have a mismatch at row 1680 in file vht.us.txt
# FUCK we have a mismatch at row 1681 in file vht.us.txt
# FUCK we have a mismatch at row 1682 in file vht.us.txt
# FUCK we have a mismatch at row 1683 in file vht.us.txt
# FUCK we have a mismatch at row 1684 in file vht.us.txt
# FUCK we have a mismatch at row 1685 in file vht.us.txt
# FUCK we have a mismatch at row 1686 in file vht.us.txt
# FUCK we have a mismatch at row 1687 in file vht.us.txt
# FUCK we have a mismatch at row 1688 in file vht.us.txt
# FUCK we have a mismatch at row 1689 in file vht.us.txt
# FUCK we have a mismatch at row 1690 in file vht.us.txt
# FUCK we have a mismatch at row 1691 in file vht.us.txt
# FUCK we have a mismatch at row 1692 in file vht.us.txt
# FUCK we have a mismatch at row 1693 in file vht.us.txt
# FUCK we have a mismatch at row 1694 in file vht.us.txt
# FUCK we have a mismatch at row 1695 in file vht.us.txt
# FUCK we have a mismatch at row 1696 in file vht.us.txt
# FUCK we have a mismatch at row 1697 in file vht.us.txt
# FUCK we have a mismatch at row 1698 in file vht.us.txt
# FUCK we have a mismatch at row 1699 in file vht.us.txt
# FUCK we have a mismatch at row 1700 in file vht.us.txt
# FUCK we have a mismatch at row 1701 in file vht.us.txt
# FUCK we have a mismatch at row 1702 in file vht.us.txt
# FUCK we have a mismatch at row 1703 in file vht.us.txt
# FUCK we have a mismatch at row 1704 in file vht.us.txt
# FUCK we have a mismatch at row 1705 in file vht.us.txt
# FUCK we have a mismatch at row 1706 in file vht.us.txt
# FUCK we have a mismatch at row 1707 in file vht.us.txt
# FUCK we have a mismatch at row 1708 in file vht.us.txt
# FUCK we have a mismatch at row 1709 in file vht.us.txt
# FUCK we have a mismatch at row 1710 in file vht.us.txt
# FUCK we have a mismatch at row 1711 in file vht.us.txt
# FUCK we have a mismatch at row 1712 in file vht.us.txt
# FUCK we have a mismatch at row 1713 in file vht.us.txt
# FUCK we have a mismatch at row 1714 in file vht.us.txt
# FUCK we have a mismatch at row 1715 in file vht.us.txt
# FUCK we have a mismatch at row 1716 in file vht.us.txt
# FUCK we have a mismatch at row 1717 in file vht.us.txt
# FUCK we have a mismatch at row 1718 in file vht.us.txt
# FUCK we have a mismatch at row 1719 in file vht.us.txt
# FUCK we have a mismatch at row 1720 in file vht.us.txt
# FUCK we have a mismatch at row 1721 in file vht.us.txt
# FUCK we have a mismatch at row 1722 in file vht.us.txt
# FUCK we have a mismatch at row 1723 in file vht.us.txt
# FUCK we have a mismatch at row 1724 in file vht.us.txt
# FUCK we have a mismatch at row 1725 in file vht.us.txt
# FUCK we have a mismatch at row 1726 in file vht.us.txt
# FUCK we have a mismatch at row 1727 in file vht.us.txt
# FUCK we have a mismatch at row 1728 in file vht.us.txt
# FUCK we have a mismatch at row 1729 in file vht.us.txt
# FUCK we have a mismatch at row 1730 in file vht.us.txt
# FUCK we have a mismatch at row 1731 in file vht.us.txt
# FUCK we have a mismatch at row 1732 in file vht.us.txt
# FUCK we have a mismatch at row 1733 in file vht.us.txt
# FUCK we have a mismatch at row 1734 in file vht.us.txt
# FUCK we have a mismatch at row 1735 in file vht.us.txt
# FUCK we have a mismatch at row 1736 in file vht.us.txt
# FUCK we have a mismatch at row 1737 in file vht.us.txt
# FUCK we have a mismatch at row 1738 in file vht.us.txt
# FUCK we have a mismatch at row 1739 in file vht.us.txt
# FUCK we have a mismatch at row 1740 in file vht.us.txt
# FUCK we have a mismatch at row 1741 in file vht.us.txt
# FUCK we have a mismatch at row 1742 in file vht.us.txt
# FUCK we have a mismatch at row 1743 in file vht.us.txt
# FUCK we have a mismatch at row 1744 in file vht.us.txt
# FUCK we have a mismatch at row 1745 in file vht.us.txt
# FUCK we have a mismatch at row 1746 in file vht.us.txt
# FUCK we have a mismatch at row 1747 in file vht.us.txt
# FUCK we have a mismatch at row 1748 in file vht.us.txt
# FUCK we have a mismatch at row 1749 in file vht.us.txt
# FUCK we have a mismatch at row 1750 in file vht.us.txt
# FUCK we have a mismatch at row 1751 in file vht.us.txt
# FUCK we have a mismatch at row 1752 in file vht.us.txt
# FUCK we have a mismatch at row 1753 in file vht.us.txt
# FUCK we have a mismatch at row 1754 in file vht.us.txt
# FUCK we have a mismatch at row 1755 in file vht.us.txt
# FUCK we have a mismatch at row 1756 in file vht.us.txt
# FUCK we have a mismatch at row 1757 in file vht.us.txt
# FUCK we have a mismatch at row 1758 in file vht.us.txt
# FUCK we have a mismatch at row 1759 in file vht.us.txt
# FUCK we have a mismatch at row 1760 in file vht.us.txt
# FUCK we have a mismatch at row 1761 in file vht.us.txt
# FUCK we have a mismatch at row 1762 in file vht.us.txt
# FUCK we have a mismatch at row 1763 in file vht.us.txt
# FUCK we have a mismatch at row 1764 in file vht.us.txt
# FUCK we have a mismatch at row 1765 in file vht.us.txt
# FUCK we have a mismatch at row 1766 in file vht.us.txt
# FUCK we have a mismatch at row 1767 in file vht.us.txt
# FUCK we have a mismatch at row 1768 in file vht.us.txt
# FUCK we have a mismatch at row 1769 in file vht.us.txt
# FUCK we have a mismatch at row 1770 in file vht.us.txt
# FUCK we have a mismatch at row 1771 in file vht.us.txt
# FUCK we have a mismatch at row 1772 in file vht.us.txt
# FUCK we have a mismatch at row 1773 in file vht.us.txt
# FUCK we have a mismatch at row 1774 in file vht.us.txt
# FUCK we have a mismatch at row 1775 in file vht.us.txt
# FUCK we have a mismatch at row 1776 in file vht.us.txt
# FUCK we have a mismatch at row 1777 in file vht.us.txt
# FUCK we have a mismatch at row 1778 in file vht.us.txt
# FUCK we have a mismatch at row 1779 in file vht.us.txt
# FUCK we have a mismatch at row 1780 in file vht.us.txt
# FUCK we have a mismatch at row 1781 in file vht.us.txt
# FUCK we have a mismatch at row 1782 in file vht.us.txt
# FUCK we have a mismatch at row 1783 in file vht.us.txt
# FUCK we have a mismatch at row 1784 in file vht.us.txt
# FUCK we have a mismatch at row 1785 in file vht.us.txt
# FUCK we have a mismatch at row 1786 in file vht.us.txt
# FUCK we have a mismatch at row 1787 in file vht.us.txt
# FUCK we have a mismatch at row 1788 in file vht.us.txt
# FUCK we have a mismatch at row 1789 in file vht.us.txt
# FUCK we have a mismatch at row 1790 in file vht.us.txt
# FUCK we have a mismatch at row 1791 in file vht.us.txt
# FUCK we have a mismatch at row 1792 in file vht.us.txt
# FUCK we have a mismatch at row 1793 in file vht.us.txt
# FUCK we have a mismatch at row 1794 in file vht.us.txt
# FUCK we have a mismatch at row 1795 in file vht.us.txt
# FUCK we have a mismatch at row 1796 in file vht.us.txt
# FUCK we have a mismatch at row 1797 in file vht.us.txt
# FUCK we have a mismatch at row 1798 in file vht.us.txt
# FUCK we have a mismatch at row 1799 in file vht.us.txt
# FUCK we have a mismatch at row 1800 in file vht.us.txt
# FUCK we have a mismatch at row 1801 in file vht.us.txt
# FUCK we have a mismatch at row 1802 in file vht.us.txt
# FUCK we have a mismatch at row 1803 in file vht.us.txt
# FUCK we have a mismatch at row 1804 in file vht.us.txt
# FUCK we have a mismatch at row 1805 in file vht.us.txt
# FUCK we have a mismatch at row 1806 in file vht.us.txt
# FUCK we have a mismatch at row 1807 in file vht.us.txt
# FUCK we have a mismatch at row 1808 in file vht.us.txt
# FUCK we have a mismatch at row 1809 in file vht.us.txt
# FUCK we have a mismatch at row 1810 in file vht.us.txt
# FUCK we have a mismatch at row 1811 in file vht.us.txt
# FUCK we have a mismatch at row 1812 in file vht.us.txt
# FUCK we have a mismatch at row 1813 in file vht.us.txt
# FUCK we have a mismatch at row 1814 in file vht.us.txt
# FUCK we have a mismatch at row 1815 in file vht.us.txt
# FUCK we have a mismatch at row 1816 in file vht.us.txt
# FUCK we have a mismatch at row 1817 in file vht.us.txt
# FUCK we have a mismatch at row 1818 in file vht.us.txt
# FUCK we have a mismatch at row 1819 in file vht.us.txt
# FUCK we have a mismatch at row 1820 in file vht.us.txt
# FUCK we have a mismatch at row 1821 in file vht.us.txt
# FUCK we have a mismatch at row 1822 in file vht.us.txt
# FUCK we have a mismatch at row 1823 in file vht.us.txt
# FUCK we have a mismatch at row 1824 in file vht.us.txt
# FUCK we have a mismatch at row 1825 in file vht.us.txt
# FUCK we have a mismatch at row 1826 in file vht.us.txt
# FUCK we have a mismatch at row 1827 in file vht.us.txt
# FUCK we have a mismatch at row 1828 in file vht.us.txt
# FUCK we have a mismatch at row 1829 in file vht.us.txt
# FUCK we have a mismatch at row 1830 in file vht.us.txt
# FUCK we have a mismatch at row 1831 in file vht.us.txt
# FUCK we have a mismatch at row 1832 in file vht.us.txt
# FUCK we have a mismatch at row 1833 in file vht.us.txt
# FUCK we have a mismatch at row 1834 in file vht.us.txt
# FUCK we have a mismatch at row 1835 in file vht.us.txt
# FUCK we have a mismatch at row 1836 in file vht.us.txt
# FUCK we have a mismatch at row 1837 in file vht.us.txt
# FUCK we have a mismatch at row 1838 in file vht.us.txt
# FUCK we have a mismatch at row 1839 in file vht.us.txt
# FUCK we have a mismatch at row 1840 in file vht.us.txt
# FUCK we have a mismatch at row 1841 in file vht.us.txt
# FUCK we have a mismatch at row 1842 in file vht.us.txt
# FUCK we have a mismatch at row 1843 in file vht.us.txt
# FUCK we have a mismatch at row 1844 in file vht.us.txt
# FUCK we have a mismatch at row 1845 in file vht.us.txt
# FUCK we have a mismatch at row 1846 in file vht.us.txt
# FUCK we have a mismatch at row 1847 in file vht.us.txt
# FUCK we have a mismatch at row 1848 in file vht.us.txt
# FUCK we have a mismatch at row 1849 in file vht.us.txt
# FUCK we have a mismatch at row 1850 in file vht.us.txt
# FUCK we have a mismatch at row 1851 in file vht.us.txt
# FUCK we have a mismatch at row 1852 in file vht.us.txt
# FUCK we have a mismatch at row 1853 in file vht.us.txt
# FUCK we have a mismatch at row 1854 in file vht.us.txt
# FUCK we have a mismatch at row 1855 in file vht.us.txt
# FUCK we have a mismatch at row 1856 in file vht.us.txt
# FUCK we have a mismatch at row 1857 in file vht.us.txt
# FUCK we have a mismatch at row 1858 in file vht.us.txt
# FUCK we have a mismatch at row 1859 in file vht.us.txt
# FUCK we have a mismatch at row 1860 in file vht.us.txt
# FUCK we have a mismatch at row 1861 in file vht.us.txt
# FUCK we have a mismatch at row 1862 in file vht.us.txt
# FUCK we have a mismatch at row 1863 in file vht.us.txt
# FUCK we have a mismatch at row 1864 in file vht.us.txt
# FUCK we have a mismatch at row 1865 in file vht.us.txt
# FUCK we have a mismatch at row 1866 in file vht.us.txt
# FUCK we have a mismatch at row 1867 in file vht.us.txt
# FUCK we have a mismatch at row 1868 in file vht.us.txt
# FUCK we have a mismatch at row 1869 in file vht.us.txt
# FUCK we have a mismatch at row 1870 in file vht.us.txt
# FUCK we have a mismatch at row 1871 in file vht.us.txt
# FUCK we have a mismatch at row 1872 in file vht.us.txt
# FUCK we have a mismatch at row 1873 in file vht.us.txt
# FUCK we have a mismatch at row 1874 in file vht.us.txt
# FUCK we have a mismatch at row 1875 in file vht.us.txt
# FUCK we have a mismatch at row 1876 in file vht.us.txt
# FUCK we have a mismatch at row 1877 in file vht.us.txt
# FUCK we have a mismatch at row 1878 in file vht.us.txt
# FUCK we have a mismatch at row 1879 in file vht.us.txt
# FUCK we have a mismatch at row 1880 in file vht.us.txt
# FUCK we have a mismatch at row 1881 in file vht.us.txt
# FUCK we have a mismatch at row 1882 in file vht.us.txt
# FUCK we have a mismatch at row 1883 in file vht.us.txt
# FUCK we have a mismatch at row 1884 in file vht.us.txt
# FUCK we have a mismatch at row 1885 in file vht.us.txt
# FUCK we have a mismatch at row 1886 in file vht.us.txt
# FUCK we have a mismatch at row 1887 in file vht.us.txt
# FUCK we have a mismatch at row 1888 in file vht.us.txt
# FUCK we have a mismatch at row 1889 in file vht.us.txt
# FUCK we have a mismatch at row 1890 in file vht.us.txt
# FUCK we have a mismatch at row 1891 in file vht.us.txt
# FUCK we have a mismatch at row 1892 in file vht.us.txt
# FUCK we have a mismatch at row 1893 in file vht.us.txt
# FUCK we have a mismatch at row 1894 in file vht.us.txt
# FUCK we have a mismatch at row 1895 in file vht.us.txt
# FUCK we have a mismatch at row 1896 in file vht.us.txt
# FUCK we have a mismatch at row 1897 in file vht.us.txt
# FUCK we have a mismatch at row 1898 in file vht.us.txt
# FUCK we have a mismatch at row 1899 in file vht.us.txt
# FUCK we have a mismatch at row 1900 in file vht.us.txt
# FUCK we have a mismatch at row 1901 in file vht.us.txt
# FUCK we have a mismatch at row 1902 in file vht.us.txt
# FUCK we have a mismatch at row 1903 in file vht.us.txt
# FUCK we have a mismatch at row 1904 in file vht.us.txt
# FUCK we have a mismatch at row 1905 in file vht.us.txt
# FUCK we have a mismatch at row 1906 in file vht.us.txt
# FUCK we have a mismatch at row 1907 in file vht.us.txt
# FUCK we have a mismatch at row 1908 in file vht.us.txt
# FUCK we have a mismatch at row 1909 in file vht.us.txt
# FUCK we have a mismatch at row 1910 in file vht.us.txt
# FUCK we have a mismatch at row 1911 in file vht.us.txt
# FUCK we have a mismatch at row 1912 in file vht.us.txt
# FUCK we have a mismatch at row 1913 in file vht.us.txt
# FUCK we have a mismatch at row 1914 in file vht.us.txt
# FUCK we have a mismatch at row 1915 in file vht.us.txt
# FUCK we have a mismatch at row 1916 in file vht.us.txt
# FUCK we have a mismatch at row 1917 in file vht.us.txt
# FUCK we have a mismatch at row 1918 in file vht.us.txt
# FUCK we have a mismatch at row 1919 in file vht.us.txt
# FUCK we have a mismatch at row 1920 in file vht.us.txt
# FUCK we have a mismatch at row 1921 in file vht.us.txt
# FUCK we have a mismatch at row 1922 in file vht.us.txt
# FUCK we have a mismatch at row 1923 in file vht.us.txt
# FUCK we have a mismatch at row 1924 in file vht.us.txt
# FUCK we have a mismatch at row 1925 in file vht.us.txt
# FUCK we have a mismatch at row 1926 in file vht.us.txt
# FUCK we have a mismatch at row 1927 in file vht.us.txt
# FUCK we have a mismatch at row 1928 in file vht.us.txt
# FUCK we have a mismatch at row 1929 in file vht.us.txt
# FUCK we have a mismatch at row 1930 in file vht.us.txt
# FUCK we have a mismatch at row 1931 in file vht.us.txt
# FUCK we have a mismatch at row 1932 in file vht.us.txt
# FUCK we have a mismatch at row 1933 in file vht.us.txt
# FUCK we have a mismatch at row 1934 in file vht.us.txt
# FUCK we have a mismatch at row 1935 in file vht.us.txt
# FUCK we have a mismatch at row 1936 in file vht.us.txt
# FUCK we have a mismatch at row 1937 in file vht.us.txt
# FUCK we have a mismatch at row 1938 in file vht.us.txt
# FUCK we have a mismatch at row 1939 in file vht.us.txt
# FUCK we have a mismatch at row 1940 in file vht.us.txt
# FUCK we have a mismatch at row 1941 in file vht.us.txt
# FUCK we have a mismatch at row 1942 in file vht.us.txt
# FUCK we have a mismatch at row 1943 in file vht.us.txt
# FUCK we have a mismatch at row 1944 in file vht.us.txt
# FUCK we have a mismatch at row 1945 in file vht.us.txt
# FUCK we have a mismatch at row 1946 in file vht.us.txt
# FUCK we have a mismatch at row 1947 in file vht.us.txt
# FUCK we have a mismatch at row 1948 in file vht.us.txt
# FUCK we have a mismatch at row 1949 in file vht.us.txt
# FUCK we have a mismatch at row 1950 in file vht.us.txt
# FUCK we have a mismatch at row 1951 in file vht.us.txt
# FUCK we have a mismatch at row 1952 in file vht.us.txt
# FUCK we have a mismatch at row 1953 in file vht.us.txt
# FUCK we have a mismatch at row 1954 in file vht.us.txt
# FUCK we have a mismatch at row 1955 in file vht.us.txt
# FUCK we have a mismatch at row 1956 in file vht.us.txt
# FUCK we have a mismatch at row 1957 in file vht.us.txt
# FUCK we have a mismatch at row 1958 in file vht.us.txt
# FUCK we have a mismatch at row 1959 in file vht.us.txt
# FUCK we have a mismatch at row 1960 in file vht.us.txt
# FUCK we have a mismatch at row 1961 in file vht.us.txt
# FUCK we have a mismatch at row 1962 in file vht.us.txt
# FUCK we have a mismatch at row 1963 in file vht.us.txt
# FUCK we have a mismatch at row 1964 in file vht.us.txt
# FUCK we have a mismatch at row 1965 in file vht.us.txt
# FUCK we have a mismatch at row 1966 in file vht.us.txt
# FUCK we have a mismatch at row 1967 in file vht.us.txt
# FUCK we have a mismatch at row 1968 in file vht.us.txt
# FUCK we have a mismatch at row 1969 in file vht.us.txt
# FUCK we have a mismatch at row 1970 in file vht.us.txt
# FUCK we have a mismatch at row 1971 in file vht.us.txt
# FUCK we have a mismatch at row 1972 in file vht.us.txt
# FUCK we have a mismatch at row 1973 in file vht.us.txt
# FUCK we have a mismatch at row 1974 in file vht.us.txt
# FUCK we have a mismatch at row 1975 in file vht.us.txt
# FUCK we have a mismatch at row 1976 in file vht.us.txt
# FUCK we have a mismatch at row 1977 in file vht.us.txt
# FUCK we have a mismatch at row 1978 in file vht.us.txt
# FUCK we have a mismatch at row 1979 in file vht.us.txt
# FUCK we have a mismatch at row 1980 in file vht.us.txt
# FUCK we have a mismatch at row 1981 in file vht.us.txt
# FUCK we have a mismatch at row 1982 in file vht.us.txt
# FUCK we have a mismatch at row 1983 in file vht.us.txt
# FUCK we have a mismatch at row 1984 in file vht.us.txt
# FUCK we have a mismatch at row 1985 in file vht.us.txt
# FUCK we have a mismatch at row 1986 in file vht.us.txt
# FUCK we have a mismatch at row 1987 in file vht.us.txt
# FUCK we have a mismatch at row 1988 in file vht.us.txt
# FUCK we have a mismatch at row 1989 in file vht.us.txt
# FUCK we have a mismatch at row 1990 in file vht.us.txt
# FUCK we have a mismatch at row 1991 in file vht.us.txt
# FUCK we have a mismatch at row 1992 in file vht.us.txt
# FUCK we have a mismatch at row 1993 in file vht.us.txt
# FUCK we have a mismatch at row 1994 in file vht.us.txt
# FUCK we have a mismatch at row 1995 in file vht.us.txt
# FUCK we have a mismatch at row 1996 in file vht.us.txt
# FUCK we have a mismatch at row 1997 in file vht.us.txt
# FUCK we have a mismatch at row 1998 in file vht.us.txt
# FUCK we have a mismatch at row 1999 in file vht.us.txt
# FUCK we have a mismatch at row 2000 in file vht.us.txt
# FUCK we have a mismatch at row 2001 in file vht.us.txt
# FUCK we have a mismatch at row 2002 in file vht.us.txt
# FUCK we have a mismatch at row 2003 in file vht.us.txt
# FUCK we have a mismatch at row 2004 in file vht.us.txt
# FUCK we have a mismatch at row 2005 in file vht.us.txt
# FUCK we have a mismatch at row 2006 in file vht.us.txt
# FUCK we have a mismatch at row 2007 in file vht.us.txt
# FUCK we have a mismatch at row 2008 in file vht.us.txt
# FUCK we have a mismatch at row 2009 in file vht.us.txt
# FUCK we have a mismatch at row 2010 in file vht.us.txt
# FUCK we have a mismatch at row 2011 in file vht.us.txt
# FUCK we have a mismatch at row 2012 in file vht.us.txt
# FUCK we have a mismatch at row 2013 in file vht.us.txt
# FUCK we have a mismatch at row 2014 in file vht.us.txt
# FUCK we have a mismatch at row 2015 in file vht.us.txt
# FUCK we have a mismatch at row 2016 in file vht.us.txt
# FUCK we have a mismatch at row 2017 in file vht.us.txt
# FUCK we have a mismatch at row 2018 in file vht.us.txt
# FUCK we have a mismatch at row 2019 in file vht.us.txt
# FUCK we have a mismatch at row 2020 in file vht.us.txt
# FUCK we have a mismatch at row 2021 in file vht.us.txt
# FUCK we have a mismatch at row 2022 in file vht.us.txt
# FUCK we have a mismatch at row 2023 in file vht.us.txt
# FUCK we have a mismatch at row 2024 in file vht.us.txt
# FUCK we have a mismatch at row 2025 in file vht.us.txt
# FUCK we have a mismatch at row 2026 in file vht.us.txt
# FUCK we have a mismatch at row 2027 in file vht.us.txt
# FUCK we have a mismatch at row 2028 in file vht.us.txt
# FUCK we have a mismatch at row 2029 in file vht.us.txt
# FUCK we have a mismatch at row 2030 in file vht.us.txt
# FUCK we have a mismatch at row 2031 in file vht.us.txt
# FUCK we have a mismatch at row 2032 in file vht.us.txt
# FUCK we have a mismatch at row 2033 in file vht.us.txt
# FUCK we have a mismatch at row 2034 in file vht.us.txt
# FUCK we have a mismatch at row 2035 in file vht.us.txt
# FUCK we have a mismatch at row 2036 in file vht.us.txt
# FUCK we have a mismatch at row 2037 in file vht.us.txt
# FUCK we have a mismatch at row 2038 in file vht.us.txt
# FUCK we have a mismatch at row 2039 in file vht.us.txt
# FUCK we have a mismatch at row 2040 in file vht.us.txt
# FUCK we have a mismatch at row 2041 in file vht.us.txt
# FUCK we have a mismatch at row 2042 in file vht.us.txt
# FUCK we have a mismatch at row 2043 in file vht.us.txt
# FUCK we have a mismatch at row 2044 in file vht.us.txt
# FUCK we have a mismatch at row 2045 in file vht.us.txt
# FUCK we have a mismatch at row 2046 in file vht.us.txt
# FUCK we have a mismatch at row 2047 in file vht.us.txt
# FUCK we have a mismatch at row 2048 in file vht.us.txt
# FUCK we have a mismatch at row 2049 in file vht.us.txt
# FUCK we have a mismatch at row 2050 in file vht.us.txt
# FUCK we have a mismatch at row 2051 in file vht.us.txt
# FUCK we have a mismatch at row 2052 in file vht.us.txt
# FUCK we have a mismatch at row 2053 in file vht.us.txt
# FUCK we have a mismatch at row 2054 in file vht.us.txt
# FUCK we have a mismatch at row 2055 in file vht.us.txt
# FUCK we have a mismatch at row 2056 in file vht.us.txt
# FUCK we have a mismatch at row 2057 in file vht.us.txt
# FUCK we have a mismatch at row 2058 in file vht.us.txt
# FUCK we have a mismatch at row 2059 in file vht.us.txt
# FUCK we have a mismatch at row 2060 in file vht.us.txt
# FUCK we have a mismatch at row 2061 in file vht.us.txt
# FUCK we have a mismatch at row 2062 in file vht.us.txt
# FUCK we have a mismatch at row 2063 in file vht.us.txt
# FUCK we have a mismatch at row 2064 in file vht.us.txt
# FUCK we have a mismatch at row 2065 in file vht.us.txt
# FUCK we have a mismatch at row 2066 in file vht.us.txt
# FUCK we have a mismatch at row 2067 in file vht.us.txt
# FUCK we have a mismatch at row 2068 in file vht.us.txt
# FUCK we have a mismatch at row 2069 in file vht.us.txt
# FUCK we have a mismatch at row 2070 in file vht.us.txt
# FUCK we have a mismatch at row 2071 in file vht.us.txt
# FUCK we have a mismatch at row 2072 in file vht.us.txt
# FUCK we have a mismatch at row 2073 in file vht.us.txt
# FUCK we have a mismatch at row 2074 in file vht.us.txt
# FUCK we have a mismatch at row 2075 in file vht.us.txt
# FUCK we have a mismatch at row 2076 in file vht.us.txt
# FUCK we have a mismatch at row 2077 in file vht.us.txt
# FUCK we have a mismatch at row 2078 in file vht.us.txt
# FUCK we have a mismatch at row 2079 in file vht.us.txt
# FUCK we have a mismatch at row 2080 in file vht.us.txt
# FUCK we have a mismatch at row 2081 in file vht.us.txt
# FUCK we have a mismatch at row 2082 in file vht.us.txt
# FUCK we have a mismatch at row 2083 in file vht.us.txt
# FUCK we have a mismatch at row 2084 in file vht.us.txt
# FUCK we have a mismatch at row 2085 in file vht.us.txt
# FUCK we have a mismatch at row 2086 in file vht.us.txt
# FUCK we have a mismatch at row 2087 in file vht.us.txt
# FUCK we have a mismatch at row 2088 in file vht.us.txt
# FUCK we have a mismatch at row 2089 in file vht.us.txt
# FUCK we have a mismatch at row 2090 in file vht.us.txt
# FUCK we have a mismatch at row 2091 in file vht.us.txt
# FUCK we have a mismatch at row 2092 in file vht.us.txt
# FUCK we have a mismatch at row 2093 in file vht.us.txt
# FUCK we have a mismatch at row 2094 in file vht.us.txt
# FUCK we have a mismatch at row 2095 in file vht.us.txt
# FUCK we have a mismatch at row 2096 in file vht.us.txt
# FUCK we have a mismatch at row 2097 in file vht.us.txt
# FUCK we have a mismatch at row 2098 in file vht.us.txt
# FUCK we have a mismatch at row 2099 in file vht.us.txt
# FUCK we have a mismatch at row 2100 in file vht.us.txt
# FUCK we have a mismatch at row 2101 in file vht.us.txt
# FUCK we have a mismatch at row 2102 in file vht.us.txt
# FUCK we have a mismatch at row 2103 in file vht.us.txt
# FUCK we have a mismatch at row 2104 in file vht.us.txt
# FUCK we have a mismatch at row 2105 in file vht.us.txt
# FUCK we have a mismatch at row 2106 in file vht.us.txt
# FUCK we have a mismatch at row 2107 in file vht.us.txt
# FUCK we have a mismatch at row 2108 in file vht.us.txt
# FUCK we have a mismatch at row 2109 in file vht.us.txt
# FUCK we have a mismatch at row 2110 in file vht.us.txt
# FUCK we have a mismatch at row 2111 in file vht.us.txt
# FUCK we have a mismatch at row 2112 in file vht.us.txt
# FUCK we have a mismatch at row 2113 in file vht.us.txt
# FUCK we have a mismatch at row 2114 in file vht.us.txt
# FUCK we have a mismatch at row 2115 in file vht.us.txt
# FUCK we have a mismatch at row 2116 in file vht.us.txt
# FUCK we have a mismatch at row 2117 in file vht.us.txt
# FUCK we have a mismatch at row 2118 in file vht.us.txt
# FUCK we have a mismatch at row 2119 in file vht.us.txt
# FUCK we have a mismatch at row 2120 in file vht.us.txt
# FUCK we have a mismatch at row 2121 in file vht.us.txt
# FUCK we have a mismatch at row 2122 in file vht.us.txt
# FUCK we have a mismatch at row 2123 in file vht.us.txt
# FUCK we have a mismatch at row 2124 in file vht.us.txt
# FUCK we have a mismatch at row 2125 in file vht.us.txt
# FUCK we have a mismatch at row 2126 in file vht.us.txt
# FUCK we have a mismatch at row 2127 in file vht.us.txt
# FUCK we have a mismatch at row 2128 in file vht.us.txt
# FUCK we have a mismatch at row 2129 in file vht.us.txt
# FUCK we have a mismatch at row 2130 in file vht.us.txt
# FUCK we have a mismatch at row 2131 in file vht.us.txt
# FUCK we have a mismatch at row 2132 in file vht.us.txt
# FUCK we have a mismatch at row 2133 in file vht.us.txt
# FUCK we have a mismatch at row 2134 in file vht.us.txt
# FUCK we have a mismatch at row 2135 in file vht.us.txt
# FUCK we have a mismatch at row 2136 in file vht.us.txt
# FUCK we have a mismatch at row 2137 in file vht.us.txt
# FUCK we have a mismatch at row 2138 in file vht.us.txt
# FUCK we have a mismatch at row 2139 in file vht.us.txt
# FUCK we have a mismatch at row 2140 in file vht.us.txt
# FUCK we have a mismatch at row 2141 in file vht.us.txt
# FUCK we have a mismatch at row 2142 in file vht.us.txt
# FUCK we have a mismatch at row 2143 in file vht.us.txt
# FUCK we have a mismatch at row 2144 in file vht.us.txt
# FUCK we have a mismatch at row 2145 in file vht.us.txt
# FUCK we have a mismatch at row 2146 in file vht.us.txt
# FUCK we have a mismatch at row 2147 in file vht.us.txt
# FUCK we have a mismatch at row 2148 in file vht.us.txt
# FUCK we have a mismatch at row 2149 in file vht.us.txt
# FUCK we have a mismatch at row 2150 in file vht.us.txt
# FUCK we have a mismatch at row 2151 in file vht.us.txt
# FUCK we have a mismatch at row 2152 in file vht.us.txt
# FUCK we have a mismatch at row 2153 in file vht.us.txt
# FUCK we have a mismatch at row 2154 in file vht.us.txt
# FUCK we have a mismatch at row 2155 in file vht.us.txt
# FUCK we have a mismatch at row 2156 in file vht.us.txt
# FUCK we have a mismatch at row 2157 in file vht.us.txt
# FUCK we have a mismatch at row 2158 in file vht.us.txt
# FUCK we have a mismatch at row 2159 in file vht.us.txt
# FUCK we have a mismatch at row 2160 in file vht.us.txt
# FUCK we have a mismatch at row 2161 in file vht.us.txt
# FUCK we have a mismatch at row 2162 in file vht.us.txt
# FUCK we have a mismatch at row 2163 in file vht.us.txt
# FUCK we have a mismatch at row 2164 in file vht.us.txt
# FUCK we have a mismatch at row 2165 in file vht.us.txt
# FUCK we have a mismatch at row 2166 in file vht.us.txt
# FUCK we have a mismatch at row 2167 in file vht.us.txt
# FUCK we have a mismatch at row 2168 in file vht.us.txt
# FUCK we have a mismatch at row 2169 in file vht.us.txt
# FUCK we have a mismatch at row 2170 in file vht.us.txt
# FUCK we have a mismatch at row 2171 in file vht.us.txt
# FUCK we have a mismatch at row 2172 in file vht.us.txt
# FUCK we have a mismatch at row 2173 in file vht.us.txt
# FUCK we have a mismatch at row 2174 in file vht.us.txt
# FUCK we have a mismatch at row 2175 in file vht.us.txt
# FUCK we have a mismatch at row 2176 in file vht.us.txt
# FUCK we have a mismatch at row 2177 in file vht.us.txt
# FUCK we have a mismatch at row 2178 in file vht.us.txt
# FUCK we have a mismatch at row 2179 in file vht.us.txt
# FUCK we have a mismatch at row 2180 in file vht.us.txt
# FUCK we have a mismatch at row 2181 in file vht.us.txt
# FUCK we have a mismatch at row 2182 in file vht.us.txt
# FUCK we have a mismatch at row 2183 in file vht.us.txt
# FUCK we have a mismatch at row 2184 in file vht.us.txt
# FUCK we have a mismatch at row 2185 in file vht.us.txt
# FUCK we have a mismatch at row 2186 in file vht.us.txt
# FUCK we have a mismatch at row 2187 in file vht.us.txt
# FUCK we have a mismatch at row 2188 in file vht.us.txt
# FUCK we have a mismatch at row 2189 in file vht.us.txt
# FUCK we have a mismatch at row 2190 in file vht.us.txt
# FUCK we have a mismatch at row 2191 in file vht.us.txt
# FUCK we have a mismatch at row 2192 in file vht.us.txt
# FUCK we have a mismatch at row 2193 in file vht.us.txt
# FUCK we have a mismatch at row 2194 in file vht.us.txt
# FUCK we have a mismatch at row 2195 in file vht.us.txt
# FUCK we have a mismatch at row 2196 in file vht.us.txt
# FUCK we have a mismatch at row 2197 in file vht.us.txt
# FUCK we have a mismatch at row 2198 in file vht.us.txt
# FUCK we have a mismatch at row 2199 in file vht.us.txt
# FUCK we have a mismatch at row 2200 in file vht.us.txt
# FUCK we have a mismatch at row 2201 in file vht.us.txt
# FUCK we have a mismatch at row 2202 in file vht.us.txt
# FUCK we have a mismatch at row 2203 in file vht.us.txt
# FUCK we have a mismatch at row 2204 in file vht.us.txt
# FUCK we have a mismatch at row 2205 in file vht.us.txt
# FUCK we have a mismatch at row 2206 in file vht.us.txt
# FUCK we have a mismatch at row 2207 in file vht.us.txt
# FUCK we have a mismatch at row 2208 in file vht.us.txt
# FUCK we have a mismatch at row 2209 in file vht.us.txt
# FUCK we have a mismatch at row 2210 in file vht.us.txt
# FUCK we have a mismatch at row 2211 in file vht.us.txt
# FUCK we have a mismatch at row 2212 in file vht.us.txt
# FUCK we have a mismatch at row 2213 in file vht.us.txt
# FUCK we have a mismatch at row 2214 in file vht.us.txt
# FUCK we have a mismatch at row 2215 in file vht.us.txt
# FUCK we have a mismatch at row 2216 in file vht.us.txt
# FUCK we have a mismatch at row 2217 in file vht.us.txt
# FUCK we have a mismatch at row 2218 in file vht.us.txt
# FUCK we have a mismatch at row 2219 in file vht.us.txt
# FUCK we have a mismatch at row 2220 in file vht.us.txt
# FUCK we have a mismatch at row 2221 in file vht.us.txt
# FUCK we have a mismatch at row 2222 in file vht.us.txt
# FUCK we have a mismatch at row 2223 in file vht.us.txt
# FUCK we have a mismatch at row 2224 in file vht.us.txt
# FUCK we have a mismatch at row 2225 in file vht.us.txt
# FUCK we have a mismatch at row 2226 in file vht.us.txt
# FUCK we have a mismatch at row 2227 in file vht.us.txt
# FUCK we have a mismatch at row 2228 in file vht.us.txt
# FUCK we have a mismatch at row 2229 in file vht.us.txt
# FUCK we have a mismatch at row 2230 in file vht.us.txt
# FUCK we have a mismatch at row 2231 in file vht.us.txt
# FUCK we have a mismatch at row 2232 in file vht.us.txt
# FUCK we have a mismatch at row 2233 in file vht.us.txt
# FUCK we have a mismatch at row 2234 in file vht.us.txt
# FUCK we have a mismatch at row 2235 in file vht.us.txt
# FUCK we have a mismatch at row 2236 in file vht.us.txt
# FUCK we have a mismatch at row 2237 in file vht.us.txt
# FUCK we have a mismatch at row 2238 in file vht.us.txt
# FUCK we have a mismatch at row 2239 in file vht.us.txt
# FUCK we have a mismatch at row 2240 in file vht.us.txt
# FUCK we have a mismatch at row 2241 in file vht.us.txt
# FUCK we have a mismatch at row 2242 in file vht.us.txt
# FUCK we have a mismatch at row 2243 in file vht.us.txt
# FUCK we have a mismatch at row 2244 in file vht.us.txt
# FUCK we have a mismatch at row 2245 in file vht.us.txt
# FUCK we have a mismatch at row 2246 in file vht.us.txt
# FUCK we have a mismatch at row 2247 in file vht.us.txt
# FUCK we have a mismatch at row 2248 in file vht.us.txt
# FUCK we have a mismatch at row 2249 in file vht.us.txt
# FUCK we have a mismatch at row 2250 in file vht.us.txt
# FUCK we have a mismatch at row 2251 in file vht.us.txt
# FUCK we have a mismatch at row 2252 in file vht.us.txt
# FUCK we have a mismatch at row 2253 in file vht.us.txt
# FUCK we have a mismatch at row 2254 in file vht.us.txt
# FUCK we have a mismatch at row 2255 in file vht.us.txt
# FUCK we have a mismatch at row 2256 in file vht.us.txt
# FUCK we have a mismatch at row 2257 in file vht.us.txt
# FUCK we have a mismatch at row 2258 in file vht.us.txt
# FUCK we have a mismatch at row 2259 in file vht.us.txt
# FUCK we have a mismatch at row 2260 in file vht.us.txt
# FUCK we have a mismatch at row 2261 in file vht.us.txt
# FUCK we have a mismatch at row 2262 in file vht.us.txt
# FUCK we have a mismatch at row 2263 in file vht.us.txt
# FUCK we have a mismatch at row 2264 in file vht.us.txt
# FUCK we have a mismatch at row 2265 in file vht.us.txt
# FUCK we have a mismatch at row 2266 in file vht.us.txt
# FUCK we have a mismatch at row 2267 in file vht.us.txt
# FUCK we have a mismatch at row 2268 in file vht.us.txt
# FUCK we have a mismatch at row 2269 in file vht.us.txt
# FUCK we have a mismatch at row 2270 in file vht.us.txt
# FUCK we have a mismatch at row 2271 in file vht.us.txt
# FUCK we have a mismatch at row 2272 in file vht.us.txt
# ...
# FUCK we have a mismatch at row 2911 in file vnq.us.txt
# FUCK we have a mismatch at row 2912 in file vnq.us.txt
# FUCK we have a mismatch at row 2913 in file vnq.us.txt
# FUCK we have a mismatch at row 2914 in file vnq.us.txt
# FUCK we have a mismatch at row 2915 in file vnq.us.txt
# FUCK we have a mismatch at row 2916 in file vnq.us.txt
# FUCK we have a mismatch at row 2917 in file vnq.us.txt
# FUCK we have a mismatch at row 2918 in file vnq.us.txt
# FUCK we have a mismatch at row 2919 in file vnq.us.txt
# FUCK we have a mismatch at row 2920 in file vnq.us.txt
# FUCK we have a mismatch at row 2921 in file vnq.us.txt
# FUCK we have a mismatch at row 2922 in file vnq.us.txt
# FUCK we have a mismatch at row 2923 in file vnq.us.txt
# FUCK we have a mismatch at row 2924 in file vnq.us.txt
# FUCK we have a mismatch at row 2925 in file vnq.us.txt
# FUCK we have a mismatch at row 2926 in file vnq.us.txt
# FUCK we have a mismatch at row 2927 in file vnq.us.txt
# FUCK we have a mismatch at row 2928 in file vnq.us.txt
# FUCK we have a mismatch at row 2929 in file vnq.us.txt
# FUCK we have a mismatch at row 2930 in file vnq.us.txt
# FUCK we have a mismatch at row 2931 in file vnq.us.txt
# FUCK we have a mismatch at row 2932 in file vnq.us.txt
# FUCK we have a mismatch at row 2933 in file vnq.us.txt
# FUCK we have a mismatch at row 2934 in file vnq.us.txt
# FUCK we have a mismatch at row 2935 in file vnq.us.txt
# FUCK we have a mismatch at row 2936 in file vnq.us.txt
# FUCK we have a mismatch at row 2937 in file vnq.us.txt
# FUCK we have a mismatch at row 2938 in file vnq.us.txt
# FUCK we have a mismatch at row 2939 in file vnq.us.txt
# FUCK we have a mismatch at row 2940 in file vnq.us.txt
# FUCK we have a mismatch at row 2941 in file vnq.us.txt
# FUCK we have a mismatch at row 2942 in file vnq.us.txt
# FUCK we have a mismatch at row 2943 in file vnq.us.txt
# FUCK we have a mismatch at row 2944 in file vnq.us.txt
# FUCK we have a mismatch at row 2945 in file vnq.us.txt
# FUCK we have a mismatch at row 2946 in file vnq.us.txt
# FUCK we have a mismatch at row 2947 in file vnq.us.txt
# FUCK we have a mismatch at row 2948 in file vnq.us.txt
# FUCK we have a mismatch at row 2949 in file vnq.us.txt
# FUCK we have a mismatch at row 2950 in file vnq.us.txt
# FUCK we have a mismatch at row 2951 in file vnq.us.txt
# FUCK we have a mismatch at row 2952 in file vnq.us.txt
# FUCK we have a mismatch at row 2953 in file vnq.us.txt
# FUCK we have a mismatch at row 2954 in file vnq.us.txt
# FUCK we have a mismatch at row 2955 in file vnq.us.txt
# FUCK we have a mismatch at row 2956 in file vnq.us.txt
# FUCK we have a mismatch at row 2957 in file vnq.us.txt
# FUCK we have a mismatch at row 2958 in file vnq.us.txt
# FUCK we have a mismatch at row 2959 in file vnq.us.txt
# FUCK we have a mismatch at row 2960 in file vnq.us.txt
# FUCK we have a mismatch at row 2961 in file vnq.us.txt
# FUCK we have a mismatch at row 2962 in file vnq.us.txt
# FUCK we have a mismatch at row 2963 in file vnq.us.txt
# FUCK we have a mismatch at row 2964 in file vnq.us.txt
# FUCK we have a mismatch at row 2965 in file vnq.us.txt
# FUCK we have a mismatch at row 2966 in file vnq.us.txt
# FUCK we have a mismatch at row 2967 in file vnq.us.txt
# FUCK we have a mismatch at row 2968 in file vnq.us.txt
# FUCK we have a mismatch at row 2969 in file vnq.us.txt
# FUCK we have a mismatch at row 2970 in file vnq.us.txt
# FUCK we have a mismatch at row 2971 in file vnq.us.txt
# FUCK we have a mismatch at row 2972 in file vnq.us.txt
# FUCK we have a mismatch at row 2973 in file vnq.us.txt
# FUCK we have a mismatch at row 2974 in file vnq.us.txt
# FUCK we have a mismatch at row 2975 in file vnq.us.txt
# FUCK we have a mismatch at row 2976 in file vnq.us.txt
# FUCK we have a mismatch at row 2977 in file vnq.us.txt
# FUCK we have a mismatch at row 2978 in file vnq.us.txt
# FUCK we have a mismatch at row 2979 in file vnq.us.txt
# FUCK we have a mismatch at row 2980 in file vnq.us.txt
# FUCK we have a mismatch at row 2981 in file vnq.us.txt
# FUCK we have a mismatch at row 2982 in file vnq.us.txt
# FUCK we have a mismatch at row 2983 in file vnq.us.txt
# FUCK we have a mismatch at row 2984 in file vnq.us.txt
# FUCK we have a mismatch at row 2985 in file vnq.us.txt
# FUCK we have a mismatch at row 2986 in file vnq.us.txt
# FUCK we have a mismatch at row 2987 in file vnq.us.txt
# FUCK we have a mismatch at row 2988 in file vnq.us.txt
# FUCK we have a mismatch at row 2989 in file vnq.us.txt
# FUCK we have a mismatch at row 2990 in file vnq.us.txt
# FUCK we have a mismatch at row 2991 in file vnq.us.txt
# FUCK we have a mismatch at row 2992 in file vnq.us.txt
# FUCK we have a mismatch at row 2993 in file vnq.us.txt
# FUCK we have a mismatch at row 2994 in file vnq.us.txt
# FUCK we have a mismatch at row 2995 in file vnq.us.txt
# FUCK we have a mismatch at row 2996 in file vnq.us.txt
# FUCK we have a mismatch at row 2997 in file vnq.us.txt
# FUCK we have a mismatch at row 2998 in file vnq.us.txt
# FUCK we have a mismatch at row 2999 in file vnq.us.txt
# FUCK we have a mismatch at row 3000 in file vnq.us.txt
# FUCK we have a mismatch at row 3001 in file vnq.us.txt
# FUCK we have a mismatch at row 3002 in file vnq.us.txt
# FUCK we have a mismatch at row 3003 in file vnq.us.txt
# FUCK we have a mismatch at row 3004 in file vnq.us.txt
# FUCK we have a mismatch at row 3005 in file vnq.us.txt
# FUCK we have a mismatch at row 3006 in file vnq.us.txt
# FUCK we have a mismatch at row 3007 in file vnq.us.txt
# FUCK we have a mismatch at row 3008 in file vnq.us.txt
# FUCK we have a mismatch at row 3009 in file vnq.us.txt
# FUCK we have a mismatch at row 3010 in file vnq.us.txt
# FUCK we have a mismatch at row 3011 in file vnq.us.txt
# FUCK we have a mismatch at row 3012 in file vnq.us.txt
# FUCK we have a mismatch at row 3013 in file vnq.us.txt
# FUCK we have a mismatch at row 3014 in file vnq.us.txt
# FUCK we have a mismatch at row 3015 in file vnq.us.txt
# FUCK we have a mismatch at row 3016 in file vnq.us.txt
# FUCK we have a mismatch at row 3017 in file vnq.us.txt
# FUCK we have a mismatch at row 3018 in file vnq.us.txt
# FUCK we have a mismatch at row 3019 in file vnq.us.txt
# FUCK we have a mismatch at row 3020 in file vnq.us.txt
# FUCK we have a mismatch at row 3021 in file vnq.us.txt
# FUCK we have a mismatch at row 3022 in file vnq.us.txt
# FUCK we have a mismatch at row 3023 in file vnq.us.txt
# FUCK we have a mismatch at row 3024 in file vnq.us.txt
# FUCK we have a mismatch at row 3025 in file vnq.us.txt
# FUCK we have a mismatch at row 3026 in file vnq.us.txt
# FUCK we have a mismatch at row 3027 in file vnq.us.txt
# FUCK we have a mismatch at row 3028 in file vnq.us.txt
# FUCK we have a mismatch at row 3029 in file vnq.us.txt
# FUCK we have a mismatch at row 3030 in file vnq.us.txt
# FUCK we have a mismatch at row 3031 in file vnq.us.txt
# FUCK we have a mismatch at row 3032 in file vnq.us.txt
# FUCK we have a mismatch at row 3033 in file vnq.us.txt
# FUCK we have a mismatch at row 3034 in file vnq.us.txt
# FUCK we have a mismatch at row 3035 in file vnq.us.txt
# FUCK we have a mismatch at row 3036 in file vnq.us.txt
# FUCK we have a mismatch at row 3037 in file vnq.us.txt
# FUCK we have a mismatch at row 3038 in file vnq.us.txt
# FUCK we have a mismatch at row 3039 in file vnq.us.txt
# FUCK we have a mismatch at row 3040 in file vnq.us.txt
# FUCK we have a mismatch at row 3041 in file vnq.us.txt
# FUCK we have a mismatch at row 3042 in file vnq.us.txt
# FUCK we have a mismatch at row 3043 in file vnq.us.txt
# FUCK we have a mismatch at row 3044 in file vnq.us.txt
# FUCK we have a mismatch at row 3045 in file vnq.us.txt
# FUCK we have a mismatch at row 3046 in file vnq.us.txt
# FUCK we have a mismatch at row 3047 in file vnq.us.txt
# FUCK we have a mismatch at row 3048 in file vnq.us.txt
# FUCK we have a mismatch at row 3049 in file vnq.us.txt
# FUCK we have a mismatch at row 3050 in file vnq.us.txt
# FUCK we have a mismatch at row 3051 in file vnq.us.txt
# FUCK we have a mismatch at row 3052 in file vnq.us.txt
# FUCK we have a mismatch at row 3053 in file vnq.us.txt
# FUCK we have a mismatch at row 3054 in file vnq.us.txt
# FUCK we have a mismatch at row 3055 in file vnq.us.txt
# FUCK we have a mismatch at row 3056 in file vnq.us.txt
# FUCK we have a mismatch at row 3057 in file vnq.us.txt
# FUCK we have a mismatch at row 3058 in file vnq.us.txt
# FUCK we have a mismatch at row 3059 in file vnq.us.txt
# FUCK we have a mismatch at row 3060 in file vnq.us.txt
# FUCK we have a mismatch at row 3061 in file vnq.us.txt
# FUCK we have a mismatch at row 3062 in file vnq.us.txt
# FUCK we have a mismatch at row 3063 in file vnq.us.txt
# FUCK we have a mismatch at row 3064 in file vnq.us.txt
# FUCK we have a mismatch at row 3065 in file vnq.us.txt
# FUCK we have a mismatch at row 3066 in file vnq.us.txt
# FUCK we have a mismatch at row 3067 in file vnq.us.txt
# FUCK we have a mismatch at row 3068 in file vnq.us.txt
# FUCK we have a mismatch at row 3069 in file vnq.us.txt
# FUCK we have a mismatch at row 3070 in file vnq.us.txt
# FUCK we have a mismatch at row 3071 in file vnq.us.txt
# FUCK we have a mismatch at row 3072 in file vnq.us.txt
# FUCK we have a mismatch at row 3073 in file vnq.us.txt
# FUCK we have a mismatch at row 3074 in file vnq.us.txt
# FUCK we have a mismatch at row 3075 in file vnq.us.txt
# FUCK we have a mismatch at row 3076 in file vnq.us.txt
# FUCK we have a mismatch at row 3077 in file vnq.us.txt
# FUCK we have a mismatch at row 3078 in file vnq.us.txt
# FUCK we have a mismatch at row 3079 in file vnq.us.txt
# FUCK we have a mismatch at row 3080 in file vnq.us.txt
# FUCK we have a mismatch at row 3081 in file vnq.us.txt
# FUCK we have a mismatch at row 3082 in file vnq.us.txt
# FUCK we have a mismatch at row 3083 in file vnq.us.txt
# FUCK we have a mismatch at row 3084 in file vnq.us.txt
# FUCK we have a mismatch at row 3085 in file vnq.us.txt
# FUCK we have a mismatch at row 3086 in file vnq.us.txt
# FUCK we have a mismatch at row 3087 in file vnq.us.txt
# FUCK we have a mismatch at row 3088 in file vnq.us.txt
# FUCK we have a mismatch at row 3089 in file vnq.us.txt
# FUCK we have a mismatch at row 3090 in file vnq.us.txt
# FUCK we have a mismatch at row 3091 in file vnq.us.txt
# FUCK we have a mismatch at row 3092 in file vnq.us.txt
# FUCK we have a mismatch at row 3093 in file vnq.us.txt
# FUCK we have a mismatch at row 3094 in file vnq.us.txt
# FUCK we have a mismatch at row 3095 in file vnq.us.txt
# FUCK we have a mismatch at row 3096 in file vnq.us.txt
# FUCK we have a mismatch at row 3097 in file vnq.us.txt
# FUCK we have a mismatch at row 3098 in file vnq.us.txt
# FUCK we have a mismatch at row 3099 in file vnq.us.txt
# FUCK we have a mismatch at row 3100 in file vnq.us.txt
# FUCK we have a mismatch at row 3101 in file vnq.us.txt
# FUCK we have a mismatch at row 3102 in file vnq.us.txt
# FUCK we have a mismatch at row 3103 in file vnq.us.txt
# FUCK we have a mismatch at row 3104 in file vnq.us.txt
# FUCK we have a mismatch at row 3105 in file vnq.us.txt
# FUCK we have a mismatch at row 3106 in file vnq.us.txt
# FUCK we have a mismatch at row 3107 in file vnq.us.txt
# FUCK we have a mismatch at row 3108 in file vnq.us.txt
# FUCK we have a mismatch at row 3109 in file vnq.us.txt
# FUCK we have a mismatch at row 3110 in file vnq.us.txt
# FUCK we have a mismatch at row 3111 in file vnq.us.txt
# FUCK we have a mismatch at row 3112 in file vnq.us.txt
# FUCK we have a mismatch at row 3113 in file vnq.us.txt
# FUCK we have a mismatch at row 3114 in file vnq.us.txt
# FUCK we have a mismatch at row 3115 in file vnq.us.txt
# FUCK we have a mismatch at row 3116 in file vnq.us.txt
# FUCK we have a mismatch at row 3117 in file vnq.us.txt
# FUCK we have a mismatch at row 3118 in file vnq.us.txt
# FUCK we have a mismatch at row 3119 in file vnq.us.txt
# FUCK we have a mismatch at row 3120 in file vnq.us.txt
# FUCK we have a mismatch at row 3121 in file vnq.us.txt
# FUCK we have a mismatch at row 3122 in file vnq.us.txt
# FUCK we have a mismatch at row 3123 in file vnq.us.txt
# FUCK we have a mismatch at row 3124 in file vnq.us.txt
# FUCK we have a mismatch at row 3125 in file vnq.us.txt
# FUCK we have a mismatch at row 3126 in file vnq.us.txt
# FUCK we have a mismatch at row 3127 in file vnq.us.txt
# FUCK we have a mismatch at row 3128 in file vnq.us.txt
# FUCK we have a mismatch at row 3129 in file vnq.us.txt
# FUCK we have a mismatch at row 3130 in file vnq.us.txt
# FUCK we have a mismatch at row 3131 in file vnq.us.txt
# FUCK we have a mismatch at row 3132 in file vnq.us.txt
# FUCK we have a mismatch at row 3133 in file vnq.us.txt
# FUCK we have a mismatch at row 3134 in file vnq.us.txt
# FUCK we have a mismatch at row 3135 in file vnq.us.txt
# FUCK we have a mismatch at row 3136 in file vnq.us.txt
# FUCK we have a mismatch at row 3137 in file vnq.us.txt
# FUCK we have a mismatch at row 3138 in file vnq.us.txt
# FUCK we have a mismatch at row 3139 in file vnq.us.txt
# FUCK we have a mismatch at row 3140 in file vnq.us.txt
# FUCK we have a mismatch at row 3141 in file vnq.us.txt
# FUCK we have a mismatch at row 3142 in file vnq.us.txt
# FUCK we have a mismatch at row 3143 in file vnq.us.txt
# FUCK we have a mismatch at row 3144 in file vnq.us.txt
# FUCK we have a mismatch at row 3145 in file vnq.us.txt
# FUCK we have a mismatch at row 3146 in file vnq.us.txt
# FUCK we have a mismatch at row 3147 in file vnq.us.txt
# FUCK we have a mismatch at row 3148 in file vnq.us.txt
# FUCK we have a mismatch at row 3149 in file vnq.us.txt
# FUCK we have a mismatch at row 3150 in file vnq.us.txt
# FUCK we have a mismatch at row 3151 in file vnq.us.txt
# FUCK we have a mismatch at row 3152 in file vnq.us.txt
# FUCK we have a mismatch at row 3153 in file vnq.us.txt
# FUCK we have a mismatch at row 3154 in file vnq.us.txt
# FUCK we have a mismatch at row 3155 in file vnq.us.txt
# FUCK we have a mismatch at row 3156 in file vnq.us.txt
# FUCK we have a mismatch at row 3157 in file vnq.us.txt
# FUCK we have a mismatch at row 3158 in file vnq.us.txt
# FUCK we have a mismatch at row 3159 in file vnq.us.txt
# FUCK we have a mismatch at row 3160 in file vnq.us.txt
# FUCK we have a mismatch at row 3161 in file vnq.us.txt
# FUCK we have a mismatch at row 3162 in file vnq.us.txt
# FUCK we have a mismatch at row 3163 in file vnq.us.txt
# FUCK we have a mismatch at row 3164 in file vnq.us.txt
# FUCK we have a mismatch at row 3165 in file vnq.us.txt
# FUCK we have a mismatch at row 3166 in file vnq.us.txt
# FUCK we have a mismatch at row 3167 in file vnq.us.txt
# FUCK we have a mismatch at row 3168 in file vnq.us.txt
# FUCK we have a mismatch at row 3169 in file vnq.us.txt
# FUCK we have a mismatch at row 3170 in file vnq.us.txt
# FUCK we have a mismatch at row 3171 in file vnq.us.txt
# FUCK we have a mismatch at row 3172 in file vnq.us.txt
# FUCK we have a mismatch at row 3173 in file vnq.us.txt
# FUCK we have a mismatch at row 3174 in file vnq.us.txt
# FUCK we have a mismatch at row 3175 in file vnq.us.txt
# FUCK we have a mismatch at row 3176 in file vnq.us.txt
# FUCK we have a mismatch at row 3177 in file vnq.us.txt
# FUCK we have a mismatch at row 3178 in file vnq.us.txt
# FUCK we have a mismatch at row 3179 in file vnq.us.txt
# FUCK we have a mismatch at row 3180 in file vnq.us.txt
# FUCK we have a mismatch at row 3181 in file vnq.us.txt
# FUCK we have a mismatch at row 3182 in file vnq.us.txt
# FUCK we have a mismatch at row 3183 in file vnq.us.txt
# FUCK we have a mismatch at row 3184 in file vnq.us.txt
# FUCK we have a mismatch at row 3185 in file vnq.us.txt
# FUCK we have a mismatch at row 3186 in file vnq.us.txt
# FUCK we have a mismatch at row 3187 in file vnq.us.txt
# FUCK we have a mismatch at row 3188 in file vnq.us.txt
# FUCK we have a mismatch at row 3189 in file vnq.us.txt
# FUCK we have a mismatch at row 3190 in file vnq.us.txt
# FUCK we have a mismatch at row 3191 in file vnq.us.txt
# FUCK we have a mismatch at row 3192 in file vnq.us.txt
# FUCK we have a mismatch at row 3193 in file vnq.us.txt
# FUCK we have a mismatch at row 3194 in file vnq.us.txt
# FUCK we have a mismatch at row 3195 in file vnq.us.txt
# FUCK we have a mismatch at row 3196 in file vnq.us.txt
# FUCK we have a mismatch at row 3197 in file vnq.us.txt
# FUCK we have a mismatch at row 3198 in file vnq.us.txt
# FUCK we have a mismatch at row 3199 in file vnq.us.txt
# FUCK we have a mismatch at row 3200 in file vnq.us.txt

# %%
extended = data_files['vaw.us.txt'][['Date','Open', 'High', 'Low', 'Close', 'Volume']]


        # Rename columns with prefix "_2"
extended.columns = [f"{col}_vaw" for col in extended.columns]

for name in file_names:
    if name != 'vaw.us.txt':
        # Select specific columns from the current DataFrame

        selected_cols = data_files[name][['Open', 'High', 'Low', 'Close', 'Volume']]

        # Rename columns with prefix "_2"
        selected_cols.columns = [f"{col}_{name[:3]}" for col in selected_cols.columns]

        # Concatenate DataFrames with renamed columns
        extended = pd.concat([extended, selected_cols], axis=1)

# %%
extended.head()
# Out:
#      Date_vaw  Open_vaw  High_vaw  Low_vaw  Close_vaw  Volume_vaw  Open_vcr  \
# 0  2005-02-25    54.737    55.614   54.737     55.594       20156    49.021
# 1  2005-02-28    55.728    55.728   54.855     55.194       47699    49.274
# 2  2005-03-01    55.418    55.640   55.041     55.130       17578    49.403
# 3  2005-03-02    54.649    55.263   54.649     55.085       11532    49.589
# 4  2005-03-03    55.409    55.409   54.855     55.122       28440    49.822
#
#    High_vcr  Low_vcr  Close_vcr  ...  Open_vht  High_vht  Low_vht  Close_vht  \
# 0    49.292   49.021     49.255  ...    46.707    47.021   46.602     47.021
# 1    49.274   49.021     49.183  ...    46.800    46.800   46.207     46.476
# 2    49.653   49.403     49.653  ...    46.622    46.791   46.622     46.753
# 3    49.969   49.589     49.784  ...    46.587    47.049   46.587     46.791
# 4    49.822   49.543     49.755  ...    46.883    46.910   46.641     46.724
#
#    Volume_vht  Open_vnq  High_vnq  Low_vnq  Close_vnq  Volume_vnq
# 0      122102    39.719    40.308   39.719     40.272       39871
# 1       13375    40.301    40.401   39.749     40.156       72024
# 2       46598    40.079    40.577   40.079     40.577       45622
# 3      160287    40.308    40.499   40.207     40.308       20521
# 4       29446    40.308    40.569   40.224     40.522       12941
#
# [5 rows x 36 columns]

# %%
file_path = os.path.join(myDrive,'ETF_Data.csv')
extended.to_csv(file_path, index=False)
